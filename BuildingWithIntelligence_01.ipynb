# %%
from openai import OpenAI

client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1",
    messages=[
        {"role": "system", "content": "You are a helpful travel assistant."},
        {"role": "user", "content": "Plan a 3-day trip to Tokyo."}
    ]
)

# Print the model's reply
print(response.choices[0].message.content)

# %%
from openai import OpenAI

# Initialize the client
client = OpenAI()

# Create a chat completion
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "You are a marketing copywriter."},
        {"role": "user", "content": "Write a catchy product description for a smart fitness watch."}
    ]
)

# Print the model's reply
print(response.choices[0].message.content)

# %%
embeddings = client.embeddings.create(
    model="text-embedding-3-small",
    input=["machine learning basics", "introduction to AI"]
)
print(embeddings.data[0].embedding[:5])  # vector representation

# %%
image = client.images.generate(
    model="gpt-image-1",
    prompt="A futuristic city skyline at sunset in watercolor style"
)
print(image.data[0].url)

# %%
audio_file = open("meeting.mp3", "rb")
transcript = client.audio.transcriptions.create(
    model="gpt-4o-mini-transcribe",
    file=audio_file
)
print(transcript.text)
